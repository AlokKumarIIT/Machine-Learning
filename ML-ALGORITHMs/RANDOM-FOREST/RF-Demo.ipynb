# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
X,y=make_classification(n_features=5,n_redundant=0,n_informative=5,n_clusters_per_class=1)

# %%
df=pd.DataFrame(X,columns=[['col1','col2','col3','col4','col5']])
df['target']=y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5 target
# 0 -1.301519 -0.730722 -0.299077  1.367637  1.550433      0
# 1 -0.202180 -1.041534 -1.676442 -0.389970  2.476532      0
# 2 -1.495997 -1.437990 -2.094796 -3.116411 -1.148312      0
# 3  2.747741 -0.040476  1.357426  0.194144  2.744089      1
# 4  1.104215  3.784403 -1.744720 -2.989925  0.208749      1

# %%
def sample_rows(df,percent):
    return df.sample(int(percent*df.shape[0]),replace=True)

# %%
def sample_cols(df,percent):
    cols=random.sample(df.columns().tolist[:,-1],int(percent*(df.shape[1]-1)))
    new_df=df[cols]
    new_df['taget']=df['target']
    return new_df

# %%
def sample_combined(df,row_percent,col_percent):
    new_df=sample_rows(df,row_percent)
    return sample_cols(new_df,col_percent)

# %%
df1=sample_rows(df,0.4)

# %%
df2=sample_rows(df,0.4)

# %%
df3=sample_rows(df,0.4)

# %%
from sklearn.tree import DecisionTreeClassifier
clf1=DecisionTreeClassifier()
clf2=DecisionTreeClassifier()
clf3=DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:5],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:5],df1.iloc[:,-1])
clf3.fit(df3.iloc[:,0:5],df1.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clf1)
# Out:
# [Text(0.5, 0.875, 'x[0] <= 0.641\ngini = 0.489\nsamples = 40\nvalue = [23, 17]'),
#  Text(0.25, 0.625, 'x[2] <= 1.202\ngini = 0.26\nsamples = 26\nvalue = [22, 4]'),
#  Text(0.125, 0.375, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.375, 0.375, 'x[4] <= 1.612\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.25, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.75, 0.625, 'x[3] <= 1.459\ngini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.625, 0.375, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.875, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.2647058823529412, 0.9545454545454546, 'x[0] <= -2.065\ngini = 0.489\nsamples = 40\nvalue = [23, 17]'),
#  Text(0.20588235294117646, 0.8636363636363636, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3235294117647059, 0.8636363636363636, 'x[4] <= 0.17\ngini = 0.47\nsamples = 37\nvalue = [23, 14]'),
#  Text(0.11764705882352941, 0.7727272727272727, 'x[0] <= 5.957\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.058823529411764705, 0.6818181818181818, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.17647058823529413, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5294117647058824, 0.7727272727272727, 'x[2] <= -0.559\ngini = 0.491\nsamples = 30\nvalue = [17, 13]'),
#  Text(0.29411764705882354, 0.6818181818181818, 'x[4] <= 2.985\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.17647058823529413, 0.5909090909090909, 'x[0] <= -0.642\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
# ...

# %%
plot_tree(clf3)
# Out:
# [Text(0.5, 0.9, 'x[4] <= 1.272\ngini = 0.489\nsamples = 40\nvalue = [23, 17]'),
#  Text(0.25, 0.7, 'x[3] <= -1.838\ngini = 0.43\nsamples = 16\nvalue = [5, 11]'),
#  Text(0.125, 0.5, 'x[0] <= -1.924\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.0625, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1875, 0.3, 'x[0] <= -1.124\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.125, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.25, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.375, 0.5, 'x[0] <= -1.888\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.3125, 0.3, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4375, 0.3, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.75, 0.7, 'x[0] <= -0.485\ngini = 0.375\nsamples = 24\nvalue = [18, 6]'),
#  Text(0.625, 0.5, 'x[0] <= -0.992\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.5625, 0.3, 'x[3] <= 0.827\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
# ...

# %%
clf1.predict(np.array([-1.301519	,-0.730722,	-0.299077,	-1.367637	,-1.550433]).reshape(1,5))
# Out:
# array([0])

# %%
clf1.predict(np.array([-1.301519	,-0.730722,	-0.299077,	-1.367637	,-1.550433]).reshape(1,5))
# Out:
# array([0])

# %%
clf1.predict(np.array([-1.301519	,-0.730722,	-0.299077,	-1.367637	,-1.550433]).reshape(1,5))
# Out:
# array([0])
